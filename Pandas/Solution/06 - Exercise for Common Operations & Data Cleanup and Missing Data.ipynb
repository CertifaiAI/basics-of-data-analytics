# %% [markdown]
# ## ![logo](../../img/license_header_logo.png)
# > **Copyright &copy; 2021 CertifAI Sdn. Bhd.**<br>
#  <br>
# This program is part of OSRFramework. You can redistribute it and/or modify
# <br>it under the terms of the GNU Affero General Public License as published by
# <br>the Free Software Foundation, either version 3 of the License, or
# <br>(at your option) any later version.
# <br>
# <br>This program is distributed in the hope that it will be useful,
# <br>but WITHOUT ANY WARRANTY; without even the implied warranty of
# <br>MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
# <br>GNU Affero General Public License for more details.
# <br>
# <br>You should have received a copy of the GNU Affero General Public License
# <br>along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %% [markdown]
# # <a name="top">06 - Exercise for Common Operations & Data Cleanup and Missing Data</a>
# Authored by: Scotrraaj Gopal - scotrraaj.gopal@certifai.ai

# %% [markdown]
# ## <a name="description">Notebook Description</a>
#
# One is able to consolidate their understanding during practical use of the knowledge. This notebook contains exercises to test your understanding and help you identify which application needs more reading and practise.
#
# By the end of this exercise, you will be able to:
#
# 1. Relate and apply the common operations in `pandas`.
# 2. Explain and apply data cleanup methods in `pandas`.
# 3. Understand, detect and deal with missing data with `pandas`.

# %% [markdown]
# ## Notebook Outline
# Here's the outline for this tutorial:
# 1. [Notebook Description](#description)
# 2. [Notebook Configurations](#configuration)
# 3. [Section I - Common Operations](#common)
# 4. [Section II - Data Cleanup and Missing Data](#missing)
# 5. [Summary](#summary)
# 6. [Reference](#reference)

# %% [markdown]
# ## <a name="configuration">Notebook Configurations</a>
#
# **Task 0:** Import `pandas` with alias `pd`.
#
# **Expected output:**
# >![05-00](../../img/pandas/05-00.png)

# %%
### BEGIN SOLUTION
import pandas as pd
### END SOLUTION


dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
#  '_lib',
#  '_libs',
#  '_np_version_under1p17',
#  '_np_version_under1p18',
#  '_testing',
#  '_tslib',
#  '_typing',
#  '_version',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %% [markdown]
# ## <a name="common">Section I - Common Operations</a>
#
# **Task I-1:** Load the CSV file at `../../Datasets/pandas/winemag-data-130k-v2.csv` in the `wine` variable and show only the first three rows.
#
# **Expected Output:**
# >![05-04](../../img/pandas/05-04.png)

# %%
### BEGIN SOLUTION
wine = pd.read_csv("../../Datasets/pandas/winemag-data-130k-v2.csv", index_col=0)
wine.head(3)
### END SOLUTION
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2  Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm

# %% [markdown]
# **Task I-2:** Extract the `description` column and assign it to the variable `desc`.
#
# **Expected Output:**
# >![06-01](../../img/pandas/06-01.png)

# %%
### BEGIN SOLUTION
desc = wine.description
# desc = wine['description']
# desc = wine.loc[:,'description']
### END SOLUTION


desc

# %% [markdown]
# **Task I-3:** Create a `DataFrame` object called `df` made up of rows with index labels `15`,`18`,`45`,`700` and column labels `country`, `province`, and `title`.
#
# **Expected Output:**
# >![06-02](../../img/pandas/06-02.png)

# %%
### BEGIN SOLUTION
df = wine.loc[[15,18,45,700],['country','province','title']]
### END SOLUTION


df

# %% [markdown]
# **Task I-4:** Generate a `DataFrame`, `df` filled with elements that lie from the 60th to 66th row and the 3rd to 7th column.
#
# **Expected Output:**
# >![06-03](../../img/pandas/06-03.png)

# %%
### BEGIN SOLUTION
df = wine.iloc[60:67,3:8]
### END SOLUTION


df

# %% [markdown]
# **Task I-5:** Generate a `DataFrame`, `top_MexicoGermany_wines` that contains all reviews from **Mexico** and **Germany** with **at least 85 points** and is **priced between 45 and 50**.
#
# **Expected Output:**
# >![06-04](../../img/pandas/06-04.png)

# %%
### BEGIN SOLUTION
top_MexicoGermany_wines = wine[(wine.country.isin(['Mexico','Germany']))&(wine.points >=85)&(wine.price>=45)&(wine.price <=50)]
top_MexicoGermany_wines.reset_index(drop=True, inplace=True)
### END SOLUTION


top_MexicoGermany_wines
# Out:
#     country                                        description  \
# 0   Germany  Verging on orange in color, this intensely bot...
# 1   Germany  Shows good varietal character in a somewhat sw...
# 2   Germany  Dr. Loosen offers a solid value in this remark...
# 3   Germany  While richly textured and boldly perfumed with...
# 4   Germany  This is a somewhat soft and friendly wine, fil...
# ..      ...                                                ...
# 90  Germany  This wine boasts a lovely nose redolent of dri...
# 91  Germany  Puckering lime zest and lemon notes are soften...
# 92  Germany  Bottling a TBA in this format makes great sens...
# 93  Germany  The von Kesselstatt estate released four GG bo...
# 94  Germany  Not quite as extremely sweet as some of the gi...
#
#                                         designation  points  price  \
# 0                                     Beerenauslese      90   47.0
# 1                    Neipperger Schlossberg Auslese      88   48.0
# 2                                           Eiswein      90   48.0
# 3           Hochheimer Domdechaney Trocken Gold Cap      90   47.0
# 4                         Von Rotliegenden Spätlese      89   45.0
# ..                                              ...     ...    ...
# 90         Trabener Würzgarten Beerenauslese 375 ml      90   49.0
# 91                   Alte Reben Trarbacher Burgberg      89   45.0
# 92  Wehlener Sonnenuhr Trockenbeerenauslese Goldkap      96   49.0
# 93                     Kaseler Nies'chen Trocken GG      88   49.0
# 94           Piesporter Goldtröpfchen Beerenauslese      92   47.0
#
#             province region_1 region_2         taster_name  \
# 0              Pfalz      NaN      NaN      Joe Czerwinski
# 1        Württemberg      NaN      NaN      Joe Czerwinski
# 2              Mosel      NaN      NaN  Anna Lee C. Iijima
# 3           Rheingau      NaN      NaN  Anna Lee C. Iijima
# 4              Pfalz      NaN      NaN      Joe Czerwinski
# ..               ...      ...      ...                 ...
# 90             Mosel      NaN      NaN      Joe Czerwinski
# 91             Mosel      NaN      NaN  Anna Lee C. Iijima
# 92  Mosel-Saar-Ruwer      NaN      NaN      Joe Czerwinski
# 93             Mosel      NaN      NaN      Joe Czerwinski
# 94  Mosel-Saar-Ruwer      NaN      NaN      Joe Czerwinski
#
#    taster_twitter_handle                                              title  \
# 0                 @JoeCz   Fitz-Ritter 2006 Beerenauslese Rieslaner (Pfalz)
# 1                 @JoeCz  Grafen Neipperg 2006 Neipperger Schlossberg Au...
# 2                    NaN           Dr. Loosen 2009 Eiswein Riesling (Mosel)
# 3                    NaN  Domdechant Werner 2013 Hochheimer Domdechaney ...
# 4                 @JoeCz  Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# ..                   ...                                                ...
# 90                @JoeCz  Max Wagner 2006 Trabener Würzgarten Beerenausl...
# 91                   NaN  Richard Böcking 2013 Alte Reben Trarbacher Bur...
# 92                @JoeCz  Dr. Loosen 2006 Wehlener Sonnenuhr Trockenbeer...
# 93                @JoeCz  Reichsgraf von Kesselstatt 2009 Kaseler Nies'c...
# 94                @JoeCz  Bollig-Lehnert 2006 Piesporter Goldtröpfchen B...
#
#       variety                      winery
# 0   Rieslaner                 Fitz-Ritter
# 1    Traminer             Grafen Neipperg
# 2    Riesling                  Dr. Loosen
# 3    Riesling           Domdechant Werner
# 4    Riesling         Ökonomierat Rebholz
# ..        ...                         ...
# 90   Riesling                  Max Wagner
# 91   Riesling             Richard Böcking
# 92   Riesling                  Dr. Loosen
# 93   Riesling  Reichsgraf von Kesselstatt
# 94   Riesling              Bollig-Lehnert
#
# [95 rows x 13 columns]

# %% [markdown]
# ## <a name="missing">Data Cleanup and Missing Data</a>
# **Task II-1:** Often the `price` column has `NaN` values. Find the total number of rows with `NaN` values in the `price` column.
#
# **Expected Output:**
# >8996

# %%
### BEGIN SOLUTION
wine.price.isna().sum()
### END SOLUTION

# %% [markdown]
# **Task II-2:** Use the string "Unknown" to replace all `NaN` values in the `DataFrame` and save it a new object, `replaced`.
#
# **Expected Output:**
#
# > ![06-05](../../img/pandas/06-05.png)

# %%
### BEGIN SOLUTION
replaced = wine.fillna("Unknown")
### END SOLUTION


replaced

# %% [markdown]
# **Task II-3:** Obtain the shape of the `DataFrame`, `processed` when all duplicated rows and rows with `NaN` values are dropped.
#
# **Expected Output:**
#
# >(20493,13)

# %%
### BEGIN SOLUTION
processed = wine.dropna().drop_duplicates()
processed.shape
### END SOLUTION

# %% [markdown]
# ##  <a name="summary">Summary</a>
# To conclude, you should now be able to:
#
# 1. Relate and apply the common operations in `pandas`.
# 2. Explain and apply data cleanup methods in `pandas`.
# 3. Understand, detect and deal with missing data with `pandas`.
#
# Congratulations, you have completed this exercise!

# %% [markdown]
# ## <a name="reference">Reference</a>
# * [Dataset Source](https://www.kaggle.com/zynicide/wine-reviews)
# * [Question Reference](https://www.kaggle.com/learn/pandas)
#
# <font size=2>[Back to Top](#top)</font>
